# %% [markdown]
# <a href="https://colab.research.google.com/github/KevHLJob/Practice-Data-Analyst/blob/main/Renewable_Energy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Enlace archivo guardado en Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Carga de dataset

# %%
data = pd.read_csv('/content/drive/MyDrive/Ciencia de datos/Practica Dataset Kaggle/ renewable_electricity_by_country.csv')
data.head(5)
# Out:
#           Country all renewables 2020 or latest year excluding hydropower  \
# 0     Afghanistan                              82.8%                 3.8%
# 1         Albania                             100.0%                 0.4%
# 2         Algeria                               1.1%                 0.9%
# 3  American Samoa                               0.0%                 0.0%
# 4          Angola                              68.2%                 1.6%
#
#   all renewables 2015 % difference 2015 vs 2020  \
# 0               86.1%                    -3.29%
# 1              100.0%                     0.00%
# 2                0.3%                     0.79%
# 3                 NaN                       NaN
# 4               54.5%                    13.72%
#
#    all electricity generation Gwh  all renewables Gwh  \
# 0                             1.1                 0.9
# 1                             5.2                 5.2
# 2                            76.7                 0.8
# ...

# %% [markdown]
# Información dataset

# %%
data.shape
# Out:
# (213, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             213 non-null    object
#  1   all renewables 2020 or latest year  213 non-null    object
#  2   excluding hydropower                213 non-null    object
#  3   all renewables 2015                 174 non-null    object
#  4   % difference 2015 vs 2020           174 non-null    object
#  5   all electricity generation Gwh      213 non-null    float64
#  6   all renewables Gwh                  213 non-null    float64
#  7   non-hydro renewables Gwh            213 non-null    float64
#  8   Notes                               7 non-null      object
#  9   Source                              6 non-null      object
# dtypes: float64(3), object(7)
# memory usage: 16.8+ KB

# %%
data.describe()
# Out:
#        all electricity generation Gwh  all renewables Gwh  \
# count                      213.000000          213.000000
# mean                       121.311737           35.681221
# std                        607.048117          172.275142
# min                          0.000000            0.000000
# 25%                          0.800000            0.100000
# 50%                          9.200000            1.800000
# 75%                         48.900000           13.900000
# max                       7601.200000         2220.500000
#
#        non-hydro renewables Gwh
# count                213.000000
# mean                  15.103239
# std                   74.794136
# min                    0.000000
# 25%                    0.010000
# 50%                    0.140000
# 75%                    2.970000
# max                  865.290000

# %% [markdown]
# Count: Value not nulls, Mean: Media, std: desviación, min: minimo valor, primer cuartil: 25%, segundo cuartil: 50%, tercer cuartil: 75%, max: maximo valor

# %%
data.columns
# Out:
# Index(['Country', 'all renewables 2020 or latest year', 'excluding hydropower',
#        'all renewables 2015', '% difference 2015 vs 2020',
#        'all electricity generation Gwh', 'all renewables Gwh',
#        'non-hydro renewables Gwh', 'Notes', 'Source'],
#       dtype='object')

# %% [markdown]
# Cambio de nombre a las columnas

# %%
data=data.rename(columns={'all renewables 2020 or latest year':'Renewables2020_and_last_year', 'excluding hydropower':'Excluding_hydropower', 'all renewables 2015':
                     'Renewables_2015', '% difference 2015 vs 2020':'%_diff_2015_vs_2020', 'all electricity generation Gwh':'Electricity_generation_gwh',
                     'all renewables Gwh':'Renewables_Gwh', 'non-hydro renewables Gwh':'non_hydro_renewables_Gwh'})

# %% [markdown]
# cambio de nombre de columnas.

# %%
data.columns
# Out:
# Index(['Country', 'Renewables2020_and_last_year', 'Excluding_hydropower',
#        'Renewables_2015', '%_diff_2015_vs_2020', 'Electricity_generation_gwh',
#        'Renewables_Gwh', 'non_hydro_renewables_Gwh', 'Notes', 'Source'],
#       dtype='object')

# %%
data.Renewables_Gwh.describe()
# Out:
# count     213.000000
# mean       35.681221
# std       172.275142
# min         0.000000
# 25%         0.100000
# 50%         1.800000
# 75%        13.900000
# max      2220.500000
# Name: Renewables_Gwh, dtype: float64

# %% [markdown]
# Parámetros específicos de la columna Renovable GWH

# %%
data.tail(5)
# Out:
#        Country Renewables2020_and_last_year Excluding_hydropower  \
# 208  Venezuela                        68.4%                 0.1%
# 209    Vietnam                        28.2%                 3.9%
# 210      Yemen                        14.6%                14.6%
# 211     Zambia                        87.0%                 1.4%
# 212   Zimbabwe                        66.0%                 1.8%
#
#     Renewables_2015 %_diff_2015_vs_2020  Electricity_generation_gwh  \
# 208           64.9%               3.50%                       105.4
# 209           37.9%              -9.70%                       214.1
# 210             NaN                 NaN                         3.4
# 211           97.1%             -10.14%                        16.0
# 212           54.0%              11.96%                        11.3
#
#      Renewables_Gwh  non_hydro_renewables_Gwh Notes Source
# 208            72.1                      0.10   NaN    NaN
# ...

# %% [markdown]
# últimos 5 registros del archivo, con todas sus columnas

# %%
data['Electricity_generation_gwh']
# Out:
# 0        1.1
# 1        5.2
# 2       76.7
# 3        0.2
# 4       13.6
#        ...
# 208    105.4
# 209    214.1
# 210      3.4
# 211     16.0
# 212     11.3
# Name: Electricity_generation_gwh, Length: 213, dtype: float64

# %%
data.loc[1:10,['Excluding_hydropower','Electricity_generation_gwh', 'Renewables_Gwh']]
# Out:
#    Excluding_hydropower  Electricity_generation_gwh  Renewables_Gwh
# 1                  0.4%                         5.2             5.2
# 2                  0.9%                        76.7             0.8
# 3                  0.0%                         0.2             0.0
# 4                  1.6%                        13.6             9.2
# 5                  0.0%                         0.0             0.0
# 6                  4.4%                         0.3             0.0
# 7                  9.5%                       137.8            37.3
# 8                  0.3%                         7.3             1.8
# 9                 16.0%                         0.9             0.1
# 10                18.4%                       243.3            59.9
